# %%
import requests
from lxml import html
from bs4 import BeautifulSoup
import re
import json

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('project-100-reviews-6063049ddd77.json', scope)
client = gspread.authorize(creds)
def GetSpreadsheetData(sheetNameurl, worksheetIndex): 
    sheet = client.open_by_url(sheetNameurl).get_worksheet(worksheetIndex) 
    return sheet.get_all_values()[1:]

# %%
spreadsheet = GetSpreadsheetData('https://docs.google.com/spreadsheets/d/13Tg3hMg5gvRycZ9eD93NnYcMCUm5BVgnB3SvvP2Hcco/edit?'+
                                 'usp=sharing', 0)

# %%
spreadsheet_df = pd.DataFrame(spreadsheet, columns=['form_timestamp', 'full_name', 'email', 'group_name', 'business_name1', 
                                                    'visit_date1', 'reviewurl', 'cocoapreneursubmit', 'pledge'])
yelp_df = spreadsheet_df[spreadsheet_df['reviewurl'].str.contains('https://www\.yelp\.com.*')]
yelp_df
# Out:
#         form_timestamp       full_name                       email  \
# 0    8/5/2020 12:06:21      Andi Halim      andihalim@berkeley.edu
# 1    8/6/2020 12:06:21      Dummy Data         dummydata@gmail.com
# 2    8/7/2020 12:06:21      Dummy Data         dummydata@gmail.com
# 3    8/8/2020 12:06:21      Dummy Data         dummydata@gmail.com
# 9   8/13/2020 12:06:21      Dummy Data         dummydata@gmail.com
# 10  8/14/2020 12:06:21      Dummy Data         dummydata@gmail.com
# 11  8/14/2020 12:06:21  Melanie Cooray  melaniecooray@berkeley.edu
#
#                group_name               business_name1 visit_date1  \
# 0   CAASI Grief to Action  Leon's Caribbean Restaurant   7/15/2020
# 1   CAASI Grief to Action           Commonplace Coffee   7/16/2020
# 2   CAASI Grief to Action           Commonplace Coffee   7/17/2020
# 3   CAASI Grief to Action                      Tsaocaa   7/18/2020
# 9   CAASI Grief to Action    Gaucho Parrilla Argentina   7/23/2020
# 10  CAASI Grief to Action    Gaucho Parrilla Argentina   7/24/2020
# 11            Berkeley CS               Tram's Kitchen    4/5/2000
#
#                                             reviewurl  \
# 0   https://www.yelp.com/biz/leons-caribbean-resta...
# 1   https://www.yelp.com/biz/commonplace-coffee-pi...
# 2   https://www.yelp.com/biz/commonplace-coffee-pi...
# 3   https://www.yelp.com/biz/tsaocaa-pittsburgh?hr...
# 9   https://www.yelp.com/biz/gaucho-parrilla-argen...
# 10  https://www.yelp.com/biz/gaucho-parrilla-argen...
# 11  https://www.yelp.com/biz/trams-kitchen-pittsbu...
#
#                               cocoapreneursubmit  \
# 0   Cannot find the business on the Cocoapreneur
# 1   Cannot find the business on the Cocoapreneur
# 2   Cannot find the business on the Cocoapreneur
# 3                                            Yes
# 9                                            Yes
# 10                                            No
# 11                                           Yes
#
#                                                pledge
# 0                                   In the next month
# 1   I do not plan on continuing to support Project...
# 2                                    In the next week
# 3   I do not plan on continuing to support Project...
# 9                              In the next two months
# 10                              In the next two weeks
# 11                                  In the next month

# %%
def get_scriptcontent(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, 'lxml')
    content = soup.find_all('script')
    return content

# %%
def get_reviews(scriptcontent):
    script_text = '<script type="application/ld+json">        {"aggregateRating":'
    counter = -1
    for rev in scriptcontent:
        counter += 1
        if str(rev)[:62] == script_text:
            reviews = str(rev)[43:]
    return reviews

# %%
def get_firstreview(reviews):
    business_name = re.findall(r'"name": (.*?),', reviews)[0].replace('"', '').replace('\\u2019', "'")
    review_dict = json.loads(re.findall(r'"review": \[(.*?), {"reviewRating":', reviews)[0])
    #searching review_dict
    review_date = review_dict['datePublished']
    review_desc = review_dict['description'].replace('\n',"")
    reviewer_name = review_dict['author']
    star_rating = list(review_dict['reviewRating'].values())[0]
    return [business_name, reviewer_name, star_rating, review_desc, review_date]

# %%
def YelpReviewScraper(urls):
    business_name, reviewer_name, star_rating, review_desc, review_date = [], [], [], [], []
    for url in urls:
        content = get_scriptcontent(url)
        reviews = get_reviews(content)
        info = get_firstreview(reviews)
        business_name.append(info[0])
        reviewer_name.append(info[1])
        star_rating.append(info[2])
        review_desc.append(info[3])
        review_date.append(info[4])
    review_data = {'business_name2': business_name, 'reviewer_name': reviewer_name,'star_rating': star_rating, \
                   'review_desc': review_desc, 'review_date': review_date, 'review_platform': 'Yelp', 'reviewurl' : urls}
    return pd.DataFrame(review_data)

# %%
reviews_df0 = YelpReviewScraper(yelp_df['reviewurl'])
reviews_df0.head()
# Out:
#        form_timestamp       full_name reviewer_name  \
# 0   8/5/2020 12:06:21      Andi Halim      Megan M.
# 1   8/6/2020 12:06:21      Dummy Data     Sophie C.
# 2   8/7/2020 12:06:21      Dummy Data        Qin G.
# 3   8/8/2020 12:06:21      Dummy Data      Maria S.
# 4  8/13/2020 12:06:21      Dummy Data     Justin H.
# 5  8/14/2020 12:06:21      Dummy Data     Lauren A.
# 6  8/14/2020 12:06:21  Melanie Cooray   Danielle K.
#
#                         email             group_name  \
# 0      andihalim@berkeley.edu  CAASI Grief to Action
# 1         dummydata@gmail.com  CAASI Grief to Action
# 2         dummydata@gmail.com  CAASI Grief to Action
# 3         dummydata@gmail.com  CAASI Grief to Action
# 4         dummydata@gmail.com  CAASI Grief to Action
# 5         dummydata@gmail.com  CAASI Grief to Action
# 6  melaniecooray@berkeley.edu            Berkeley CS
#
#                 business_name1               business_name2 visit_date1  \
# 0  Leon's Caribbean Restaurant  Leon's Caribbean Restaurant   7/15/2020
# 1           Commonplace Coffee           Commonplace Coffee   7/16/2020
# 2           Commonplace Coffee           Commonplace Coffee   7/17/2020
# 3                      Tsaocaa                      Tsaocaa   7/18/2020
# 4    Gaucho Parrilla Argentina    Gaucho Parrilla Argentina   7/23/2020
# 5    Gaucho Parrilla Argentina    Gaucho Parrilla Argentina   7/24/2020
# 6               Tram's Kitchen               Tram's Kitchen    4/5/2000
#
#   review_date review_platform  \
# 0  2020-06-05            Yelp
# 1  2018-11-20            Yelp
# 2  2020-02-03            Yelp
# 3  2020-07-09            Yelp
# 4  2020-07-20            Yelp
# 5  2019-12-13            Yelp
# 6  2020-07-22            Yelp
#
#                                            reviewurl  \
# 0  https://www.yelp.com/biz/leons-caribbean-resta...
# 1  https://www.yelp.com/biz/commonplace-coffee-pi...
# 2  https://www.yelp.com/biz/commonplace-coffee-pi...
# 3  https://www.yelp.com/biz/tsaocaa-pittsburgh?hr...
# 4  https://www.yelp.com/biz/gaucho-parrilla-argen...
# 5  https://www.yelp.com/biz/gaucho-parrilla-argen...
# 6  https://www.yelp.com/biz/trams-kitchen-pittsbu...
#
#                                          review_desc  star_rating  \
# 0  We ordered take out of brown stew chicken, a s...            5
# 1  Great coffee shop! Reasonable prices for great...            5
# 2  I used to live in sq hill and this was my go t...            5
# 3  This is a great bubble tea spot. The staff was...            5
# 4  Great Steaks, pork chops, chicken, basically a...            5
# 5  Great steak sandwich. I was impressed by the s...            5
# 6  Tram's Kitchen is a hidden gem that my family ...            5
#
#                              cocoapreneursubmit  \
# 0  Cannot find the business on the Cocoapreneur
# 1  Cannot find the business on the Cocoapreneur
# 2  Cannot find the business on the Cocoapreneur
# 3                                           Yes
# 4                                           Yes
# 5                                            No
# 6                                           Yes
#
#                                               pledge
# 0                                  In the next month
# 1  I do not plan on continuing to support Project...
# 2                                   In the next week
# 3  I do not plan on continuing to support Project...
# 4                             In the next two months
# 5                              In the next two weeks
# 6                                  In the next month

# %%
reviews_df = yelp_df.merge(reviews_df0, on="reviewurl")[['form_timestamp','full_name', 'reviewer_name','email',
                                                         'group_name','business_name1', 'business_name2','visit_date1', 
                                                         'review_date','review_platform','reviewurl','review_desc', 
                                                         'star_rating', 'cocoapreneursubmit','pledge']]
reviews_df
# Out:
#        form_timestamp       full_name reviewer_name  \
# 0   8/5/2020 12:06:21      Andi Halim      Megan M.
# 1   8/6/2020 12:06:21      Dummy Data     Sophie C.
# 2   8/7/2020 12:06:21      Dummy Data        Qin G.
# 3   8/8/2020 12:06:21      Dummy Data      Maria S.
# 4  8/13/2020 12:06:21      Dummy Data     Justin H.
# 5  8/14/2020 12:06:21      Dummy Data     Lauren A.
# 6  8/14/2020 12:06:21  Melanie Cooray   Danielle K.
#
#                         email             group_name  \
# 0      andihalim@berkeley.edu  CAASI Grief to Action
# 1         dummydata@gmail.com  CAASI Grief to Action
# 2         dummydata@gmail.com  CAASI Grief to Action
# 3         dummydata@gmail.com  CAASI Grief to Action
# 4         dummydata@gmail.com  CAASI Grief to Action
# 5         dummydata@gmail.com  CAASI Grief to Action
# 6  melaniecooray@berkeley.edu            Berkeley CS
#
#                 business_name1               business_name2 visit_date1  \
# 0  Leon's Caribbean Restaurant  Leon's Caribbean Restaurant   7/15/2020
# 1           Commonplace Coffee           Commonplace Coffee   7/16/2020
# 2           Commonplace Coffee           Commonplace Coffee   7/17/2020
# 3                      Tsaocaa                      Tsaocaa   7/18/2020
# 4    Gaucho Parrilla Argentina    Gaucho Parrilla Argentina   7/23/2020
# 5    Gaucho Parrilla Argentina    Gaucho Parrilla Argentina   7/24/2020
# 6               Tram's Kitchen               Tram's Kitchen    4/5/2000
#
#   review_date review_platform  \
# 0  2020-06-05            Yelp
# 1  2018-11-20            Yelp
# 2  2020-02-03            Yelp
# 3  2020-07-09            Yelp
# 4  2020-07-20            Yelp
# 5  2019-12-13            Yelp
# 6  2020-07-22            Yelp
#
#                                            reviewurl  \
# 0  https://www.yelp.com/biz/leons-caribbean-resta...
# 1  https://www.yelp.com/biz/commonplace-coffee-pi...
# 2  https://www.yelp.com/biz/commonplace-coffee-pi...
# 3  https://www.yelp.com/biz/tsaocaa-pittsburgh?hr...
# 4  https://www.yelp.com/biz/gaucho-parrilla-argen...
# 5  https://www.yelp.com/biz/gaucho-parrilla-argen...
# 6  https://www.yelp.com/biz/trams-kitchen-pittsbu...
#
#                                          review_desc  star_rating  \
# 0  We ordered take out of brown stew chicken, a s...            5
# 1  Great coffee shop! Reasonable prices for great...            5
# 2  I used to live in sq hill and this was my go t...            5
# 3  This is a great bubble tea spot. The staff was...            5
# 4  Great Steaks, pork chops, chicken, basically a...            5
# 5  Great steak sandwich. I was impressed by the s...            5
# 6  Tram's Kitchen is a hidden gem that my family ...            5
#
#                              cocoapreneursubmit  \
# 0  Cannot find the business on the Cocoapreneur
# 1  Cannot find the business on the Cocoapreneur
# 2  Cannot find the business on the Cocoapreneur
# 3                                           Yes
# 4                                           Yes
# 5                                            No
# 6                                           Yes
#
#                                               pledge
# 0                                  In the next month
# 1  I do not plan on continuing to support Project...
# 2                                   In the next week
# 3  I do not plan on continuing to support Project...
# 4                             In the next two months
# 5                              In the next two weeks
# 6                                  In the next month

# %%
reviews_df.to_csv('yelpreviews_df.csv', index=False)

# %%
#for public production, I should use the Google and Yelp API's but I created 
#web crawlers at first before I learned about Terms of Service and limits
#on scraping, especially for use in public production.
