# %%
import requests
from lxml import html
from bs4 import BeautifulSoup
import re
import json

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('project-100-reviews-6063049ddd77.json', scope)
client = gspread.authorize(creds)
def GetSpreadsheetData(sheetNameurl, worksheetIndex): 
    sheet = client.open_by_url(sheetNameurl).get_worksheet(worksheetIndex) 
    return sheet.get_all_values()[1:]

# %%
spreadsheet = GetSpreadsheetData('https://docs.google.com/spreadsheets/d/13Tg3hMg5gvRycZ9eD93NnYcMCUm5BVgnB3SvvP2Hcco/edit?'+
                                 'usp=sharing', 0)

# %%
spreadsheet_df = pd.DataFrame(spreadsheet, columns=['form_timestamp', 'full_name', 'email', 'group_name', 'business_name1', 
                                                    'visit_date1', 'reviewurl', 'cocoapreneursubmit', 'pledge'])
google_df = spreadsheet_df[spreadsheet_df['reviewurl'].str.contains('https://goo\.gl/maps/.*')]

# %%
def get_metacontent(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, 'lxml')
    metas = soup.find_all('meta')
    content_array = [i.get('content') for i in metas]
    return content_array

# %%
#star rating and review description
def get_review(content_arr):
    star_rating0, review_desc0 = [], []
    for c in content_arr:
        match = re.match(r'[★]+', c)
        if match != None:
            star_rating0.append(len(match[0]))
            review_desc0.append(re.findall(r'[^\'★☆].*', c))
    star_rating0 = np.mean(star_rating0)
    review_desc0 = review_desc0[0][0][1:].replace('"', "")
    return star_rating0, review_desc0

# %%
#reviewer name and business name
def get_review_names(content_arr):
    reviewer_name0, business_name0 = [], []
    for c in content_arr: 
        match = re.findall(r'Google review of (.*?) by (.*)', c)
        if match != []:
            reviewer_name0.append(match[0][0])
            business_name0.append(match[0][1])
    return reviewer_name0[0], business_name0[0]

# %%
def GoogleReviewScraper(urls):
    star_rating, review_desc, reviewer_name, business_name = [], [], [], []
    for url in urls:
        content = get_metacontent(url)
        review, names = get_review(content), get_review_names(content)
        star_rating.append(review[0])
        review_desc.append(review[1])
        business_name.append(names[0])
        reviewer_name.append(names[1])
    review_data = {'business_name2': business_name, 'reviewer_name': reviewer_name,'star_rating': star_rating, \
                   'review_desc': review_desc, 'review_platform': 'Google', 'reviewurl':urls}
    return pd.DataFrame(review_data)

# %%
reviews_df0 = GoogleReviewScraper(google_df['reviewurl'])
reviews_df0.head()
# Out:
#           business_name2      reviewer_name  star_rating  \
# 4        Sichuan Gourmet  Thilo Krah-Tomala          5.0
# 5        Sichuan Gourmet        Shauna Bigi          1.0
# 6        Sichuan Gourmet              Jen C          4.0
# 7        Sichuan Gourmet         Jason Chen          2.0
# 8  Leon's Caribbean Food         Andi Halim          5.0
#
#                                          review_desc review_platform  \
# 4  Great Chinese eatery with spicy Sichuan food. ...          Google
# 5  Placed an order for take out...amazing crispy ...          Google
# 6  Some dishes were great but others were miss . ...          Google
# 7  i think they have changed the chief. The taste...          Google
# 8  Had the goat curry and oxtail plates along wit...          Google
#
#                                reviewurl
# 4  https://goo.gl/maps/81AHC82LizDEuf2w9
# 5  https://goo.gl/maps/FHBkpX2xwGb5HFSK8
# 6  https://goo.gl/maps/cqBhkSw8Q7tN34Fv8
# 7  https://goo.gl/maps/65NqTgESVgc8S2hZ9
# 8  https://goo.gl/maps/htQVrTNeBUDZusvy7

# %%
reviews_df = google_df.merge(reviews_df0, on="reviewurl")[['form_timestamp','full_name', 'reviewer_name','email','group_name',
                                                           'business_name1', 'business_name2','visit_date1', 
                                                           'review_platform','reviewurl','review_desc', 'star_rating', 
                                                           'cocoapreneursubmit','pledge']]
reviews_df
# Out:
#        form_timestamp   full_name      reviewer_name                email  \
# 0   8/9/2020 12:06:21  Dummy Data  Thilo Krah-Tomala  dummydata@gmail.com
# 1  8/10/2020 12:06:21  Dummy Data        Shauna Bigi  dummydata@gmail.com
# 2  8/11/2020 12:06:21  Dummy Data              Jen C  dummydata@gmail.com
# 3  8/12/2020 12:06:21  Dummy Data         Jason Chen  dummydata@gmail.com
# 4   8/5/2020 12:06:21  Dummy Data         Andi Halim  dummydata@gmail.com
#
#               group_name               business_name1         business_name2  \
# 0  CAASI Grief to Action              Sichuan Gourmet        Sichuan Gourmet
# 1  CAASI Grief to Action              Sichuan Gourmet        Sichuan Gourmet
# 2  CAASI Grief to Action              Sichuan Gourmet        Sichuan Gourmet
# 3  CAASI Grief to Action              Sichuan Gourmet        Sichuan Gourmet
# 4  CAASI Grief to Action  Leon's Caribbean Restaurant  Leon's Caribbean Food
#
#   visit_date1 review_platform                              reviewurl  \
# 0   7/19/2020          Google  https://goo.gl/maps/81AHC82LizDEuf2w9
# 1   7/20/2020          Google  https://goo.gl/maps/FHBkpX2xwGb5HFSK8
# 2   7/21/2020          Google  https://goo.gl/maps/cqBhkSw8Q7tN34Fv8
# 3   7/22/2020          Google  https://goo.gl/maps/65NqTgESVgc8S2hZ9
# 4   7/15/2020          Google  https://goo.gl/maps/htQVrTNeBUDZusvy7
#
#                                          review_desc  star_rating  \
# 0  Great Chinese eatery with spicy Sichuan food. ...          5.0
# 1  Placed an order for take out...amazing crispy ...          1.0
# 2  Some dishes were great but others were miss . ...          4.0
# 3  i think they have changed the chief. The taste...          2.0
# 4  Had the goat curry and oxtail plates along wit...          5.0
#
#                              cocoapreneursubmit  \
# 0  Cannot find the business on the Cocoapreneur
# 1  Cannot find the business on the Cocoapreneur
# 2  Cannot find the business on the Cocoapreneur
# 3  Cannot find the business on the Cocoapreneur
# 4  Cannot find the business on the Cocoapreneur
#
#                                               pledge
# 0  I do not plan on continuing to support Project...
# 1  I do not plan on continuing to support Project...
# 2  I do not plan on continuing to support Project...
# 3                              In the next two weeks
# 4                                  In the next month

# %%
reviews_df.to_csv('googlereviews_df.csv', index=False)
